# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/2-ExploracionDataframes.csv', sep=';')
df
# Out:
#          CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                     1101       Iquique                    11
# 1                     1101       Iquique                    11
# 2                     1101       Iquique                    11
# 3                     1101       Iquique                    11
# 4                     1101       Iquique                    11
# ...                    ...           ...                   ...
# 6489667              16305   San Nicolás                   163
# 6489668              16305   San Nicolás                   163
# 6489669              16305   San Nicolás                   163
# 6489670              16305   San Nicolás                   163
# 6489671              16305   San Nicolás                   163
#
#         Provincia Origen  CUT Region Origen Region Origen  CUT Comuna Destino  \
# 0                Iquique                  1      Tarapacá                1402
# ...
