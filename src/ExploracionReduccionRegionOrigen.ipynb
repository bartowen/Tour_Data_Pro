# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/df_listo_para_segmentar.csv',sep=';')

df
# Out:
#          CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                     1101       Iquique                    11
# 1                     1101       Iquique                    11
# 2                     1101       Iquique                    11
# 3                     1101       Iquique                    11
# 4                     1101       Iquique                    11
# ...                    ...           ...                   ...
# 2952619              16305   San Nicolás                   163
# 2952620              16305   San Nicolás                   163
# 2952621              16305   San Nicolás                   163
# 2952622              16305   San Nicolás                   163
# 2952623              16305   San Nicolás                   163
#
#         Provincia Origen  CUT Region Origen Region Origen  CUT Comuna Destino  \
# 0                Iquique                  1      Tarapacá                1402
# 1                Iquique                  1      Tarapacá                1403
# 2                Iquique                  1      Tarapacá                1404
# 3                Iquique                  1      Tarapacá                1405
# 4                Iquique                  1      Tarapacá                2101
# ...                  ...                ...           ...                 ...
# 2952619          Punilla                 16         Ñuble               16203
# 2952620          Punilla                 16         Ñuble               16207
# 2952621          Punilla                 16         Ñuble               16302
# 2952622          Punilla                 16         Ñuble               16303
# 2952623          Punilla                 16         Ñuble               16304
#
#         Comuna Destino  CUT Destino Turistico              Destino Turistico  \
# 0               Camiña                      0                         Camiña
# 1             Colchane                      1  Colchane - P.N. Volcán Isluga
# 2                Huara                      2          Resto región Tarapacá
# 3                 Pica                      3                           Pica
# 4          Antofagasta                      4                    Antofagasta
# ...                ...                    ...                            ...
# 2952619        Coelemu                     87                Valle del Itata
# 2952620       Treguaco                     83             Resto región Ñuble
# 2952621       Coihueco                     83             Resto región Ñuble
# 2952622         Ñiquén                     83             Resto región Ñuble
# 2952623     San Fabián                     92                     San Fabián
#
#          ...  Anio CUT Mes        Mes Viajes Ocasionales  CUT Temporada  \
# 0        ...  2019       1      enero                109              1
# 1        ...  2019       1      enero                298              1
# 2        ...  2019       1      enero               2594              1
# 3        ...  2019       1      enero               4138              1
# 4        ...  2019       1      enero               2071              1
# ...      ...   ...     ...        ...                ...            ...
# 2952619  ...  2023      12  diciembre                 17              1
# 2952620  ...  2023      12  diciembre                 44              1
# 2952621  ...  2023      12  diciembre                108              1
# 2952622  ...  2023      12  diciembre                 47              1
# 2952623  ...  2023      12  diciembre                 26              1
#
#          Temporada PIB Region Origen  PIB Region Destino  Norte a Sur Origen  \
# 0             Alta       1061.580205         1061.580205                   2
# 1             Alta       1061.580205         1061.580205                   2
# 2             Alta       1061.580205         1061.580205                   2
# 3             Alta       1061.580205         1061.580205                   2
# 4             Alta       1061.580205         3724.530431                   2
# ...            ...               ...                 ...                 ...
# 2952619       Alta        833.567298          833.567298                  10
# 2952620       Alta        833.567298          833.567298                  10
# 2952621       Alta        833.567298          833.567298                  10
# 2952622       Alta        833.567298          833.567298                  10
# 2952623       Alta        833.567298          833.567298                  10
#
#         Norte a Sur Destino
# 0                         2
# 1                         2
# 2                         2
# 3                         2
# 4                         3
# ...                     ...
# 2952619                  10
# 2952620                  10
# 2952621                  10
# 2952622                  10
# 2952623                  10
#
# [2952624 rows x 24 columns]

# %%
df.shape
# Out:
# (2952624, 24)

# %%
df.columns
# Out:
# Index(['CUT Comuna Origen', 'Comuna Origen', 'CUT Provincia Origen',
#        'Provincia Origen', 'CUT Region Origen', 'Region Origen',
#        'CUT Comuna Destino', 'Comuna Destino', 'CUT Destino Turistico',
#        'Destino Turistico', 'CUT Provincia Destino', 'Provincia Destino',
#        'CUT Region Destino', 'Region Destino', 'Anio', 'CUT Mes', 'Mes',
#        'Viajes Ocasionales', 'CUT Temporada', 'Temporada', 'PIB Region Origen',
#        'PIB Region Destino', 'Norte a Sur Origen', 'Norte a Sur Destino'],
#       dtype='object')

# %%
# Elimina las columnas 'Destino Turístico' y 'CUT Destino Turístico', 
df = df.drop(columns=['Destino Turistico', 'CUT Destino Turistico','Norte a Sur Origen', 'Norte a Sur Destino'])

# %%
df.head()
# Out:
#    CUT Comuna Origen Comuna Origen  CUT Provincia Origen Provincia Origen  \
# 0               1101       Iquique                    11          Iquique
# 1               1101       Iquique                    11          Iquique
# 2               1101       Iquique                    11          Iquique
# 3               1101       Iquique                    11          Iquique
# 4               1101       Iquique                    11          Iquique
#
#    CUT Region Origen Region Origen  CUT Comuna Destino Comuna Destino  \
# 0                  1      Tarapacá                1402         Camiña
# 1                  1      Tarapacá                1403       Colchane
# 2                  1      Tarapacá                1404          Huara
# 3                  1      Tarapacá                1405           Pica
# 4                  1      Tarapacá                2101    Antofagasta
#
#    CUT Provincia Destino Provincia Destino  CUT Region Destino Region Destino  \
# 0                     14         Tamarugal                   1       Tarapacá
# 1                     14         Tamarugal                   1       Tarapacá
# 2                     14         Tamarugal                   1       Tarapacá
# 3                     14         Tamarugal                   1       Tarapacá
# 4                     21       Antofagasta                   2    Antofagasta
#
#    Anio  CUT Mes    Mes  Viajes Ocasionales  CUT Temporada Temporada  \
# 0  2019        1  enero                 109              1      Alta
# 1  2019        1  enero                 298              1      Alta
# 2  2019        1  enero                2594              1      Alta
# 3  2019        1  enero                4138              1      Alta
# 4  2019        1  enero                2071              1      Alta
#
#    PIB Region Origen  PIB Region Destino
# 0        1061.580205         1061.580205
# 1        1061.580205         1061.580205
# 2        1061.580205         1061.580205
# 3        1061.580205         1061.580205
# 4        1061.580205         3724.530431

# %%
df = df.drop(columns=['Provincia Origen', 'Comuna Origen', 'CUT Comuna Origen', 'CUT Provincia Origen','CUT Provincia Destino', 'Provincia Destino'])

# %%
# Renombrar las columnas
df = df.rename(columns={'CUT Temporada': 'Num Temporada', 'CUT Mes': 'Num Mes'})

df
# Out:
#          CUT Region Origen Region Origen  CUT Comuna Destino Comuna Destino  \
# 0                        1      Tarapacá                1402         Camiña
# 1                        1      Tarapacá                1403       Colchane
# 2                        1      Tarapacá                1404          Huara
# 3                        1      Tarapacá                1405           Pica
# 4                        1      Tarapacá                2101    Antofagasta
# ...                    ...           ...                 ...            ...
# 2952619                 16         Ñuble               16203        Coelemu
# 2952620                 16         Ñuble               16207       Treguaco
# 2952621                 16         Ñuble               16302       Coihueco
# 2952622                 16         Ñuble               16303         Ñiquén
# 2952623                 16         Ñuble               16304     San Fabián
#
#          CUT Region Destino Region Destino  Anio  Num Mes        Mes  \
# 0                         1       Tarapacá  2019        1      enero
# 1                         1       Tarapacá  2019        1      enero
# 2                         1       Tarapacá  2019        1      enero
# 3                         1       Tarapacá  2019        1      enero
# 4                         2    Antofagasta  2019        1      enero
# ...                     ...            ...   ...      ...        ...
# 2952619                  16          Ñuble  2023       12  diciembre
# 2952620                  16          Ñuble  2023       12  diciembre
# 2952621                  16          Ñuble  2023       12  diciembre
# 2952622                  16          Ñuble  2023       12  diciembre
# 2952623                  16          Ñuble  2023       12  diciembre
#
#          Viajes Ocasionales  Num Temporada Temporada  PIB Region Origen  \
# 0                       109              1      Alta        1061.580205
# 1                       298              1      Alta        1061.580205
# 2                      2594              1      Alta        1061.580205
# 3                      4138              1      Alta        1061.580205
# 4                      2071              1      Alta        1061.580205
# ...                     ...            ...       ...                ...
# 2952619                  17              1      Alta         833.567298
# 2952620                  44              1      Alta         833.567298
# 2952621                 108              1      Alta         833.567298
# 2952622                  47              1      Alta         833.567298
# 2952623                  26              1      Alta         833.567298
#
#          PIB Region Destino
# 0               1061.580205
# 1               1061.580205
# 2               1061.580205
# 3               1061.580205
# 4               3724.530431
# ...                     ...
# 2952619          833.567298
# 2952620          833.567298
# 2952621          833.567298
# 2952622          833.567298
# 2952623          833.567298
#
# [2952624 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['CUT Region Origen', 'Region Origen', 'CUT Comuna Destino',
#        'Comuna Destino', 'CUT Region Destino', 'Region Destino', 'Anio',
#        'Num Mes', 'Mes', 'Viajes Ocasionales', 'Num Temporada', 'Temporada',
#        'PIB Region Origen', 'PIB Region Destino'],
#       dtype='object')

# %%
# Definir el nuevo orden de las columnas

column_order = ['CUT Region Origen', 'Region Origen', 'CUT Region Destino', 'Region Destino', 
                'CUT Comuna Destino', 'Comuna Destino', 'Anio', 'Num Mes', 'Mes', 
                'Num Temporada', 'Temporada', 'Viajes Ocasionales', 'PIB Region Origen', 
                'PIB Region Destino']

# Reordenar las columnas en el DataFrame
df = df[column_order]

df
# Out:
#          CUT Region Origen Region Origen  CUT Region Destino Region Destino  \
# 0                        1      Tarapacá                   1       Tarapacá
# 1                        1      Tarapacá                   1       Tarapacá
# 2                        1      Tarapacá                   1       Tarapacá
# 3                        1      Tarapacá                   1       Tarapacá
# 4                        1      Tarapacá                   2    Antofagasta
# ...                    ...           ...                 ...            ...
# 2952619                 16         Ñuble                  16          Ñuble
# 2952620                 16         Ñuble                  16          Ñuble
# 2952621                 16         Ñuble                  16          Ñuble
# 2952622                 16         Ñuble                  16          Ñuble
# 2952623                 16         Ñuble                  16          Ñuble
#
#          CUT Comuna Destino Comuna Destino  Anio  Num Mes        Mes  \
# 0                      1402         Camiña  2019        1      enero
# 1                      1403       Colchane  2019        1      enero
# 2                      1404          Huara  2019        1      enero
# 3                      1405           Pica  2019        1      enero
# 4                      2101    Antofagasta  2019        1      enero
# ...                     ...            ...   ...      ...        ...
# 2952619               16203        Coelemu  2023       12  diciembre
# 2952620               16207       Treguaco  2023       12  diciembre
# 2952621               16302       Coihueco  2023       12  diciembre
# 2952622               16303         Ñiquén  2023       12  diciembre
# 2952623               16304     San Fabián  2023       12  diciembre
#
#          Num Temporada Temporada  Viajes Ocasionales  PIB Region Origen  \
# 0                    1      Alta                 109        1061.580205
# 1                    1      Alta                 298        1061.580205
# 2                    1      Alta                2594        1061.580205
# 3                    1      Alta                4138        1061.580205
# 4                    1      Alta                2071        1061.580205
# ...                ...       ...                 ...                ...
# 2952619              1      Alta                  17         833.567298
# 2952620              1      Alta                  44         833.567298
# 2952621              1      Alta                 108         833.567298
# 2952622              1      Alta                  47         833.567298
# 2952623              1      Alta                  26         833.567298
#
#          PIB Region Destino
# 0               1061.580205
# 1               1061.580205
# 2               1061.580205
# 3               1061.580205
# 4               3724.530431
# ...                     ...
# 2952619          833.567298
# 2952620          833.567298
# 2952621          833.567298
# 2952622          833.567298
# 2952623          833.567298
#
# [2952624 rows x 14 columns]

# %%
# Agrupar por las columnas
df_grouped = df.groupby(['Region Origen', 'Comuna Destino', 'Region Destino', 'Anio', 'Mes'], as_index=False).agg({
    'Viajes Ocasionales': 'sum',            # Sumar los viajes ocasionales
    'PIB Region Origen': 'first',           # Mantener el primer valor del PIB de la región de origen
    'PIB Region Destino': 'first',          # Mantener el primer valor del PIB de la región de destino
    'Temporada': 'first',                   # Mantener el primer valor de la temporada
    'CUT Region Origen': 'first',           # Mantener el primer valor de CUT Region Origen
    'CUT Comuna Destino': 'first',          # Mantener el primer valor de CUT Comuna Destino
    'CUT Region Destino': 'first',          # Mantener el primer valor de CUT Region Destino
    'Num Mes': 'first',                     # Mantener el primer valor de Num Mes
    'Num Temporada': 'first'                # Mantener el primer valor de Num Temporada
})

# Reordenar las columnas para mantener el mismo orden que el df original
df_grouped = df_grouped[['CUT Region Origen', 'Region Origen', 'CUT Region Destino', 'Region Destino', 
                        'CUT Comuna Destino', 'Comuna Destino', 'Anio', 'Num Mes', 'Mes', 
                        'Num Temporada', 'Temporada', 'Viajes Ocasionales', 
                        'PIB Region Origen', 'PIB Region Destino']]

df_grouped
# Out:
#         CUT Region Origen Region Origen  CUT Region Destino  \
# 0                       2   Antofagasta                  11
# 1                       2   Antofagasta                  11
# 2                       2   Antofagasta                  11
# 3                       2   Antofagasta                  11
# 4                       2   Antofagasta                  11
# ...                   ...           ...                 ...
# 290149                 16         Ñuble                  13
# 290150                 16         Ñuble                  13
# 290151                 16         Ñuble                  13
# 290152                 16         Ñuble                  13
# 290153                 16         Ñuble                  13
#
#                                    Region Destino  CUT Comuna Destino  \
# 0       Aysén del General Carlos Ibáñez del Campo               11201
# 1       Aysén del General Carlos Ibáñez del Campo               11201
# 2       Aysén del General Carlos Ibáñez del Campo               11201
# 3       Aysén del General Carlos Ibáñez del Campo               11201
# 4       Aysén del General Carlos Ibáñez del Campo               11201
# ...                                           ...                 ...
# 290149                  Metropolitana de Santiago               13120
# 290150                  Metropolitana de Santiago               13120
# 290151                  Metropolitana de Santiago               13120
# 290152                  Metropolitana de Santiago               13120
# 290153                  Metropolitana de Santiago               13120
#
#        Comuna Destino  Anio  Num Mes        Mes  Num Temporada Temporada  \
# 0               Aisén  2019        4      abril              0      Baja
# 1               Aisén  2019        8     agosto              0      Baja
# 2               Aisén  2019       12  diciembre              1      Alta
# 3               Aisén  2019        1      enero              1      Alta
# 4               Aisén  2019        2    febrero              1      Alta
# ...               ...   ...      ...        ...            ...       ...
# 290149          Ñuñoa  2024        1      enero              1      Alta
# 290150          Ñuñoa  2024        2    febrero              1      Alta
# 290151          Ñuñoa  2024        6      junio              0      Baja
# 290152          Ñuñoa  2024        3      marzo              0      Baja
# 290153          Ñuñoa  2024        5       mayo              0      Baja
#
#         Viajes Ocasionales  PIB Region Origen  PIB Region Destino
# 0                       13        3894.124564          308.139915
# 1                       12        4099.144469          314.027098
# 2                       10        4279.561800          315.639897
# 3                       52        3724.530431          296.813161
# 4                       45        3724.530431          296.813161
# ...                    ...                ...                 ...
# 290149                 636         852.296102        21124.552771
# 290150                 599         852.296102        21124.552771
# 290151                 684         801.797197        21484.966717
# 290152                 998         852.296102        21124.552771
# 290153                 687         801.797197        21484.966717
#
# [290154 rows x 14 columns]

# %%
comuna_especifica_region_fecha = df[
    (df['Comuna Destino'] == 'Camiña') & 
    (df['Anio'] == 2023) & 
    (df['Mes'] == 'enero') & 
    (df['Region Origen'] == 'Tarapacá')
]

comuna_especifica_region_fecha
# Out:
#       CUT Region Origen Region Origen  CUT Region Destino Region Destino  \
# 944                   1      Tarapacá                   1       Tarapacá
# 1966                  1      Tarapacá                   1       Tarapacá
# 2509                  1      Tarapacá                   1       Tarapacá
# 2713                  1      Tarapacá                   1       Tarapacá
# 2769                  1      Tarapacá                   1       Tarapacá
# 3293                  1      Tarapacá                   1       Tarapacá
#
#       CUT Comuna Destino Comuna Destino  Anio  Num Mes    Mes  Num Temporada  \
# 944                 1402         Camiña  2023        1  enero              1
# 1966                1402         Camiña  2023        1  enero              1
# 2509                1402         Camiña  2023        1  enero              1
# 2713                1402         Camiña  2023        1  enero              1
# 2769                1402         Camiña  2023        1  enero              1
# 3293                1402         Camiña  2023        1  enero              1
#
#      Temporada  Viajes Ocasionales  PIB Region Origen  PIB Region Destino
# 944       Alta                 698        1172.444308         1172.444308
# 1966      Alta                 821        1172.444308         1172.444308
# 2509      Alta                  55        1172.444308         1172.444308
# 2713      Alta                   6        1172.444308         1172.444308
# 2769      Alta                  50        1172.444308         1172.444308
# 3293      Alta                   8        1172.444308         1172.444308

# %%
comuna_especifica_region_fecha_2 = df_grouped[
    (df_grouped['Comuna Destino'] == 'Camiña') & 
    (df_grouped['Anio'] == 2023) & 
    (df_grouped['Mes'] == 'enero') & 
    (df_grouped['Region Origen'] == 'Tarapacá')
]

comuna_especifica_region_fecha_2
# Out:
#         CUT Region Origen Region Origen  CUT Region Destino Region Destino  \
# 234201                  1      Tarapacá                   1       Tarapacá
#
#         CUT Comuna Destino Comuna Destino  Anio  Num Mes    Mes  \
# 234201                1402         Camiña  2023        1  enero
#
#         Num Temporada Temporada  Viajes Ocasionales  PIB Region Origen  \
# 234201              1      Alta                1638        1172.444308
#
#         PIB Region Destino
# 234201         1172.444308

# %%
df = df_grouped

df
# Out:
#         CUT Region Origen Region Origen  CUT Region Destino  \
# 0                       2   Antofagasta                  11
# 1                       2   Antofagasta                  11
# 2                       2   Antofagasta                  11
# 3                       2   Antofagasta                  11
# 4                       2   Antofagasta                  11
# ...                   ...           ...                 ...
# 290149                 16         Ñuble                  13
# 290150                 16         Ñuble                  13
# 290151                 16         Ñuble                  13
# 290152                 16         Ñuble                  13
# 290153                 16         Ñuble                  13
#
#                                    Region Destino  CUT Comuna Destino  \
# 0       Aysén del General Carlos Ibáñez del Campo               11201
# 1       Aysén del General Carlos Ibáñez del Campo               11201
# 2       Aysén del General Carlos Ibáñez del Campo               11201
# 3       Aysén del General Carlos Ibáñez del Campo               11201
# 4       Aysén del General Carlos Ibáñez del Campo               11201
# ...                                           ...                 ...
# 290149                  Metropolitana de Santiago               13120
# 290150                  Metropolitana de Santiago               13120
# 290151                  Metropolitana de Santiago               13120
# 290152                  Metropolitana de Santiago               13120
# 290153                  Metropolitana de Santiago               13120
#
#        Comuna Destino  Anio  Num Mes        Mes  Num Temporada Temporada  \
# 0               Aisén  2019        4      abril              0      Baja
# 1               Aisén  2019        8     agosto              0      Baja
# 2               Aisén  2019       12  diciembre              1      Alta
# 3               Aisén  2019        1      enero              1      Alta
# 4               Aisén  2019        2    febrero              1      Alta
# ...               ...   ...      ...        ...            ...       ...
# 290149          Ñuñoa  2024        1      enero              1      Alta
# 290150          Ñuñoa  2024        2    febrero              1      Alta
# 290151          Ñuñoa  2024        6      junio              0      Baja
# 290152          Ñuñoa  2024        3      marzo              0      Baja
# 290153          Ñuñoa  2024        5       mayo              0      Baja
#
#         Viajes Ocasionales  PIB Region Origen  PIB Region Destino
# 0                       13        3894.124564          308.139915
# 1                       12        4099.144469          314.027098
# 2                       10        4279.561800          315.639897
# 3                       52        3724.530431          296.813161
# 4                       45        3724.530431          296.813161
# ...                    ...                ...                 ...
# 290149                 636         852.296102        21124.552771
# 290150                 599         852.296102        21124.552771
# 290151                 684         801.797197        21484.966717
# 290152                 998         852.296102        21124.552771
# 290153                 687         801.797197        21484.966717
#
# [290154 rows x 14 columns]

# %%
df.to_csv('../data/processed/df_segmento_Reduccion_region_origen_comuna_destino.csv', sep=';', index=False)

# %%
#Verificar las temporadas

import seaborn as sns
import matplotlib.pyplot as plt
import math

# Visualizar temporadas por región

regiones = df['Region Destino'].unique()

# Calcular el número de filas y columnas necesario para que quede bien las regiones

n_regiones = len(regiones)
n_cols = 3
n_rows = math.ceil(n_regiones / n_cols)  # Calcular el número de filas necesario

plt.figure(figsize=(16, n_rows * 5))  # Ajustar el tamaño de la figura

# Iterar sobre cada región para crear un subplot

for i, region in enumerate(regiones, 1):
    # Crear un subplot para cada región
    plt.subplot(n_rows, n_cols, i)
    
    # Filtrar los datos por región actual

    data_region = df[df['Region Destino'] == region]
    
    # Crear el gráfico por temporada

    sns.barplot(data=data_region, x='Mes', y='Viajes Ocasionales', hue='Temporada', dodge=False,
                palette={'Alta': 'red', 'Baja': 'blue'})
    
    
    plt.title(f'Temporada Alta y Baja - {region}', fontsize=14)
    plt.xlabel('Mes', fontsize=12)
    plt.ylabel('Total de Viajes Ocasionales', fontsize=12)
    plt.xticks(rotation=45)
    plt.legend(title='Temporada')

plt.tight_layout()
plt.show()
