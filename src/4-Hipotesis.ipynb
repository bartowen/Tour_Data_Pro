# %%
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv('../data/processed/df_listo_para_eda.csv', sep=';')

# %%
# Filtrar el dataframe para incluir todos los datos
# Asumiendo que df es tu dataframe original con todas las filas

# Separar los datos por temporada
alta = df[df['Temporada'] == 'Alta']['Viajes Ocasionales']
baja = df[df['Temporada'] == 'Baja']['Viajes Ocasionales']

# Realizar el t-test
t_stat, p_value = stats.ttest_ind(alta, baja)

# Mostrar resultados
print(f"Estadístico t: {t_stat}, Valor p: {p_value}")

# Interpretar el resultado
alpha = 0.05
if p_value <= alpha:
    print("Rechazamos la hipótesis nula. Hay una diferencia significativa en la cantidad de viajes.")
else:
    print("No podemos rechazar la hipótesis nula. No hay evidencia de una diferencia significativa.")
# Out:
# Estadístico t: nan, Valor p: nan
# No podemos rechazar la hipótesis nula. No hay evidencia de una diferencia significativa.

# %%
# Supongamos que ya tienes tu dataframe llamado 'df'
# Filtrar filas que contienen al menos un NaN
df_nan = df[df.isna().any(axis=1)]

# Mostrar el dataframe filtrado
df_nan[df_nan['Region Destino']=='Tarapacá']
# Out:
#          CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 5594                  1402        Camiña                    14
# 5618                  1402        Camiña                    14
# 5648                  1402        Camiña                    14
# 5762                  1403      Colchane                    14
# 5764                  1403      Colchane                    14
# ...                    ...           ...                   ...
# 6489126              16305   San Nicolás                   163
# 6489405              16305   San Nicolás                   163
# 6489406              16305   San Nicolás                   163
# 6489407              16305   San Nicolás                   163
# 6489408              16305   San Nicolás                   163
#
#         Provincia Origen  CUT Region Origen Region Origen  CUT Comuna Destino  \
# 5594           Tamarugal                  1      Tarapacá                1405
# 5618           Tamarugal                  1      Tarapacá                1405
# 5648           Tamarugal                  1      Tarapacá                1405
# 5762           Tamarugal                  1      Tarapacá                1402
# 5764           Tamarugal                  1      Tarapacá                1405
# ...                  ...                ...           ...                 ...
# 6489126          Punilla                 16         Ñuble                1404
# 6489405          Punilla                 16         Ñuble                1101
# 6489406          Punilla                 16         Ñuble                1107
# 6489407          Punilla                 16         Ñuble                1401
# 6489408          Punilla                 16         Ñuble                1405
#
#         Comuna Destino      Destino Turistico  CUT Provincia Destino  ...  \
# 5594              Pica                   Pica                     14  ...
# 5618              Pica                   Pica                     14  ...
# 5648              Pica                   Pica                     14  ...
# 5762            Camiña                 Camiña                     14  ...
# 5764              Pica                   Pica                     14  ...
# ...                ...                    ...                    ...  ...
# 6489126          Huara  Resto región Tarapacá                     14  ...
# 6489405        Iquique                Iquique                     11  ...
# 6489406  Alto Hospicio  Resto región Tarapacá                     11  ...
# 6489407   Pozo Almonte                 Mamiña                     14  ...
# 6489408           Pica                   Pica                     14  ...
#
#          Anio  CUT Mes        Mes  Viajes Ocasionales  Temporada  \
# 5594     2020        1      enero                 NaN       Alta
# 5618     2021        1      enero                 NaN       Alta
# 5648     2022        1      enero                 NaN       Alta
# 5762     2019        1      enero                 NaN       Alta
# 5764     2019        1      enero                 NaN       Alta
# ...       ...      ...        ...                 ...        ...
# 6489126  2023       12  diciembre                 NaN       Alta
# 6489405  2024       12  diciembre                 NaN       Alta
# 6489406  2024       12  diciembre                 NaN       Alta
# 6489407  2024       12  diciembre                 NaN       Alta
# 6489408  2024       12  diciembre                 NaN       Alta
#
#         PIB Region Origen  PIB Region Destino Total Temporada Region  \
# 5594          1136.354511         1136.354511               236857.0
# 5618          1106.772123         1106.772123               171309.0
# 5648          1173.454337         1173.454337               222964.0
# 5762          1061.580205         1061.580205               272938.0
# 5764          1061.580205         1061.580205               272938.0
# ...                   ...                 ...                    ...
# 6489126        833.567298         1345.905667               246151.0
# 6489405               NaN                 NaN               242742.0
# 6489406               NaN                 NaN               242742.0
# 6489407               NaN                 NaN               242742.0
# 6489408               NaN                 NaN               242742.0
#
#          Total Temporada Provincia  Total Temporada Comuna
# 5594                       69779.0                 25128.0
# 5618                       58965.0                 19047.0
# 5648                       81072.0                 23929.0
# 5762                       78851.0                  1298.0
# 5764                       78851.0                 22500.0
# ...                            ...                     ...
# 6489126                   100236.0                 25871.0
# 6489405                   128816.0                114172.0
# 6489406                   128816.0                 14644.0
# 6489407                   113926.0                 38873.0
# 6489408                   113926.0                 37022.0
#
# [59590 rows x 23 columns]

# %%
# Verificar la cantidad de NaN por columna
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# CUT Comuna Origen                  0
# Comuna Origen                      0
# CUT Provincia Origen               0
# Provincia Origen                   0
# CUT Region Origen                  0
# Region Origen                      0
# CUT Comuna Destino                 0
# Comuna Destino                     0
# Destino Turistico                  0
# CUT Provincia Destino              0
# Provincia Destino                  0
# CUT Region Destino                 0
# Region Destino                     0
# Anio                               0
# CUT Mes                            0
# Mes                                0
# Viajes Ocasionales           3027301
# Temporada                          0
# PIB Region Origen             527820
# PIB Region Destino            527820
# Total Temporada Region             0
# Total Temporada Provincia          0
# Total Temporada Comuna             0
# dtype: int64

# %%
# Filtrar filas donde 'PIB Region Destino' es NaN
df_nan_pib = df[df['PIB Region Destino'].isna()]

# Mostrar el dataframe filtrado
df_nan_pib.describe()
# Out:
#        CUT Comuna Origen  CUT Provincia Origen  CUT Region Origen  \
# count      527820.000000         527820.000000      527820.000000
# mean         8956.239388             89.502205           8.720439
# std          3787.560836             37.862591           3.815943
# min          1101.000000             11.000000           1.000000
# 25%          6107.000000             61.000000           6.000000
# 50%          8304.000000             83.000000           8.000000
# 75%         13107.000000            131.000000          13.000000
# max         16305.000000            163.000000          16.000000
#
#        CUT Comuna Destino  CUT Provincia Destino  CUT Region Destino  \
# count       527820.000000          527820.000000       527820.000000
# mean          9048.218461              90.422371            8.814619
# std           3766.011492              37.647854            3.795079
# min           1101.000000              11.000000            1.000000
# 25%           6111.000000              61.000000            6.000000
# 50%           8313.000000              83.000000            8.000000
# 75%          13107.000000             131.000000           13.000000
# max          16305.000000             163.000000           16.000000
#
#            Anio        CUT Mes  Viajes Ocasionales  PIB Region Origen  \
# count  527820.0  527820.000000        56796.000000                0.0
# mean     2024.0       9.500000           52.994507                NaN
# std         0.0       1.707827          204.872172                NaN
# min      2024.0       7.000000            1.000000                NaN
# 25%      2024.0       8.000000            4.000000                NaN
# 50%      2024.0       9.500000           10.000000                NaN
# 75%      2024.0      11.000000           32.000000                NaN
# max      2024.0      12.000000        11415.000000                NaN
#
#        PIB Region Destino  Total Temporada Region  Total Temporada Provincia  \
# count                 0.0            5.278200e+05               5.278200e+05
# mean                  NaN            1.206667e+06               4.401134e+05
# std                   NaN            6.857644e+05               4.118192e+05
# min                   NaN            6.377200e+04               1.206000e+03
# 25%                   NaN            8.682200e+05               1.288160e+05
# 50%                   NaN            1.089556e+06               2.878250e+05
# 75%                   NaN            1.677241e+06               5.593850e+05
# max                   NaN            2.547614e+06               1.570178e+06
#
#        Total Temporada Comuna
# count           527820.000000
# mean             41674.432549
# std              49487.462543
# min                 79.000000
# 25%              13659.000000
# 50%              24084.000000
# 75%              44189.000000
# max             346534.000000
