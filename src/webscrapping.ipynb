# %% [markdown]
# Exploración Web Scrapping para descargar CSV Viajes Ocasionales (Sernatur)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Definición de url y headers para el Web Scrapping

url = 'https://www.sernatur.cl/dataturismo/big-data-turismo-interno/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# Se realiza el get a la página web

response = requests.get(url, headers=headers)

# Verificación de status

if response.status_code == 403:
    print("Acceso prohibido: El servidor bloquea el acceso.")
else:
    # Se convierte la respuesta HTML en un objeto soup
    soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="es-CL">
# <head>
# <!-- Google Tag Manager -->
# <script>
#         (function(w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start': new Date().getTime(),
#                 event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-K6CVNCM');
#     </script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <!-- FavIcon test-->
# ...

# %%
# Búsqueda de botones por su etiqueta < a > y atributo href 

botones = soup.find_all('a', href=True)  # Encuentra todos los enlaces
botones
# Out:
# [<a class="block" href="https://www.sernatur.cl">
#  <img alt="logo-sernatur" class="sernatur-logo" src="https://www.sernatur.cl/wp-content/uploads/2020/12/LOGOWEB.png"/>
#  </a>,
#  <a class="col-xs-4 col-sm-3 col-md-1" href="#">
#  <img alt="logo-buscador" src="https://www.sernatur.cl/wp-content/uploads/2018/03/icono-buscar.svg"/>
#  </a>,
# ...

# %%
#  Búsqueda de los URL que puedan contener el .csv o alguna descarga (download)

csv_url = []
for boton in botones:
    if '.csv' in boton['href'] or 'download' in boton['href']:
        csv_url.append(boton['href'])
print("Lista URL con CSV:", csv_url)
# Out:
# Lista URL con CSV: ['https://www.sernatur.cl/wp-content/uploads/2020/11/Viajes-ocasionales-1.csv', 'https://www.sernatur.cl/wp-content/uploads/2020/11/Viajes-totales-1.csv']

# %%
# Se identifica el csv de interés (Viajes Ocasionales)

url_viajes_ocasionales_csv = csv_url[0]
url_viajes_ocasionales_csv
# Out:
# 'https://www.sernatur.cl/wp-content/uploads/2020/11/Viajes-ocasionales-1.csv'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response = requests.get(url_viajes_ocasionales_csv,headers=headers)

# Se Guarda el csv obtenido

with open("../data/raw/viajes_ocasionales.csv", "wb") as file:
    file.write(response.content)

# %%
# Comprobación

df = pd.read_csv('../data/raw/viajes_ocasionales.csv', sep=';')
df
# Out:
#         CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                    1101       Iquique                    11
# 1                    1101       Iquique                    11
# 2                    1101       Iquique                    11
# 3                    1101       Iquique                    11
# 4                    1101       Iquique                    11
# ...                   ...           ...                   ...
# 540801              16305   San Nicolás                   163
# 540802              16305   San Nicolás                   163
# 540803              16305   San Nicolás                   163
# 540804              16305   San Nicolás                   163
# 540805              16305   San Nicolás                   163
#
#        Provincia Origen   CUT Region Origen  Region Origen   \
# 0                Iquique                   1       Tarapacá
# 1                Iquique                   1       Tarapacá
# ...

# %% [markdown]
# Exploración para descargar CSV PIB Regional (API Banco Central De Chile)

# %%
import os
import numpy as np
import bcchapi
from dotenv import load_dotenv

# %%
# Se extraen las credenciales necesarias del .env

load_dotenv()

client_id = os.environ.get('USUARIO_BCC')
client_secret = os.environ.get('SECRET_BCC')

# Se crea la conexión con la api del BCCH

siete = bcchapi.Siete(client_id, client_secret)

# Se realiza la consulta para conseguir el ID de las series que necesitamos

respuesta=siete.buscar("PIB Región de Antofagasta")

print(respuesta.to_string())
# Out:
#                                seriesId frequencyCode                                                                                                                        spanishTitle                                                                                                     englishTitle firstObservation lastObservation  updatedAt  createdAt
# 0  F035.PIB.FLU.N.CLP.2018.Z.Z.Z.02.0.T     QUARTERLY                          PIB Región de Antofagasta, precios corrientes,  precios corrientes, base 2018 (miles de millones de pesos)                                  GDP, Region of Antofagasta,  current prices, reference 2018 (billions of pesos)              NaT             NaT 2022-05-25 2022-01-31
# ...

# %%
# Diccionario de ID de las series y sus regiones

dic_serie_region = {
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.15.0.T": "Arica y Parinacota",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.01.0.T": "Tarapacá",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.02.0.T": "Antofagasta",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.03.0.T": "Atacama",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.04.0.T": "Coquimbo",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.05.0.T": "Valparaíso",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.13.0.T": "Metropolitana de Santiago",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.06.0.T": "Libertador Gral. Bernardo O'Higgins",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.07.0.T": "Maule",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.16.0.T": "Ñuble",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.08.0.T": "Biobío",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.09.0.T": "La Araucanía",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.14.0.T": "Los Ríos",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.10.0.T": "Los Lagos",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.11.0.T": "Aysén del General Carlos Ibáñez del Campo",
    "F035.PIB.FLU.R.CLP.2018.Z.Z.Z.12.0.T": "Magallanes y de la Antártica Chilena"
}

# Obtener listas de nombres de regiones y códigos

nombres_regiones = list(dic_serie_region.values())
id_series = list(dic_serie_region.keys())

# %%
# Consulta a BCCHAPI de las series que se requieren

df = siete.cuadro(
    series=id_series,   
    nombres =nombres_regiones
)

df
# Out:
#             Arica y Parinacota     Tarapacá  Antofagasta      Atacama  \
# 2013-01-01          278.304651   811.931803  3759.318361   871.758026
# 2013-04-01          306.132341   926.814620  3949.000465   845.358870
# 2013-07-01          338.475536  1044.963002  3792.362453   867.192979
# 2013-10-01          321.351073  1135.992471  4133.677309   975.218096
# 2014-01-01          285.116735   977.620431  3803.705319   905.985208
# 2014-04-01          330.556785   990.721233  4204.009406   868.805299
# 2014-07-01          325.580361   954.180471  3887.046755   939.175426
# 2014-10-01          336.348957  1087.410974  4338.462348   982.605582
# 2015-01-01          292.839070   972.588507  4075.279764   931.414412
# 2015-04-01          322.130679  1030.833009  4165.907748   880.653764
# 2015-07-01          350.488783   945.295703  3868.235912   880.348463
# 2015-10-01          353.493088  1075.746516  4082.728044   983.250652
# ...

# %%
# Restablecer el índice y convertirlo en una columna

df.reset_index(inplace=True)

# Renombrar la columna que ahora contiene las fechas

df.rename(columns={'index': 'fecha'}, inplace=True)

df
# Out:
#         fecha  Arica y Parinacota     Tarapacá  Antofagasta      Atacama  \
# 0  2013-01-01          278.304651   811.931803  3759.318361   871.758026
# 1  2013-04-01          306.132341   926.814620  3949.000465   845.358870
# 2  2013-07-01          338.475536  1044.963002  3792.362453   867.192979
# 3  2013-10-01          321.351073  1135.992471  4133.677309   975.218096
# 4  2014-01-01          285.116735   977.620431  3803.705319   905.985208
# 5  2014-04-01          330.556785   990.721233  4204.009406   868.805299
# 6  2014-07-01          325.580361   954.180471  3887.046755   939.175426
# 7  2014-10-01          336.348957  1087.410974  4338.462348   982.605582
# 8  2015-01-01          292.839070   972.588507  4075.279764   931.414412
# 9  2015-04-01          322.130679  1030.833009  4165.907748   880.653764
# 10 2015-07-01          350.488783   945.295703  3868.235912   880.348463
# 11 2015-10-01          353.493088  1075.746516  4082.728044   983.250652
# ...

# %%
# Transponer el DataFrame

df_transpuesto = df.set_index('fecha').T
df_transpuesto
# Out:
# fecha                                        2013-01-01    2013-04-01  \
# Arica y Parinacota                           278.304651    306.132341
# Tarapacá                                     811.931803    926.814620
# Antofagasta                                 3759.318361   3949.000465
# Atacama                                      871.758026    845.358870
# Coquimbo                                    1426.567416   1413.417680
# Valparaíso                                  3339.833326   3371.955157
# Metropolitana de Santiago                  16843.137386  17862.986368
# Libertador General Bernardo O'Higgins       1931.429678   1708.125163
# Maule                                       1599.502893   1610.473179
# Ñuble                                        634.644423    650.654310
# Biobío                                      2301.626148   2475.065928
# La Araucanía                                1172.639779   1068.709189
# ...
