# %%
import pandas as pd

# %%
# Lectura del DataFrame

df_viajes_ocasionales = pd.read_csv('../data/raw/viajes_ocasionales.csv', sep=';')

# Transformación a int

meses = ['enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre','diciembre']
for mes in meses:
    df_viajes_ocasionales[mes] = df_viajes_ocasionales[mes].round(0).astype('Int64')

df_viajes_ocasionales
# Out:
#         CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                    1101       Iquique                    11
# 1                    1101       Iquique                    11
# 2                    1101       Iquique                    11
# 3                    1101       Iquique                    11
# 4                    1101       Iquique                    11
# ...                   ...           ...                   ...
# 540801              16305   San Nicolás                   163
# 540802              16305   San Nicolás                   163
# 540803              16305   San Nicolás                   163
# 540804              16305   San Nicolás                   163
# 540805              16305   San Nicolás                   163
#
#        Provincia Origen   CUT Region Origen  Region Origen   \
# 0                Iquique                   1       Tarapacá
# 1                Iquique                   1       Tarapacá
# 2                Iquique                   1       Tarapacá
# 3                Iquique                   1       Tarapacá
# 4                Iquique                   1       Tarapacá
# ...                  ...                 ...            ...
# 540801           Punilla                  16          Ñuble
# 540802           Punilla                  16          Ñuble
# 540803           Punilla                  16          Ñuble
# 540804           Punilla                  16          Ñuble
# 540805           Punilla                  16          Ñuble
#
#         CUT Comuna Destino  Comuna Destino              Destino Turistico   \
# 0                      1402          Camiña                         Camiña
# 1                      1403        Colchane  Colchane - P.N. Volcán Isluga
# 2                      1404           Huara          Resto región Tarapacá
# 3                      1405            Pica                           Pica
# 4                      2101     Antofagasta                    Antofagasta
# ...                     ...             ...                            ...
# 540801                16203         Coelemu                Valle del Itata
# 540802                16207        Treguaco             Resto región Ñuble
# 540803                16302        Coihueco             Resto región Ñuble
# 540804                16303          Ñiquén             Resto región Ñuble
# 540805                16304      San Fabián                     San Fabián
#
#         CUT Provincia Destino   ... marzo  abril  mayo  junio  julio  agosto  \
# 0                           14  ...    34    106   100     15     26      25
# 1                           14  ...   110    139   100     69    169     158
# 2                           14  ...  1064   2086  1522    973   1574    6450
# 3                           14  ...   933   1653  1569    935   1485    1613
# 4                           21  ...   899   1069  1850    749   1116    1644
# ...                        ...  ...   ...    ...   ...    ...    ...     ...
# 540801                     162  ...    15     25     9     31      8    <NA>
# 540802                     162  ...    15     28    39     57     52    <NA>
# 540803                     163  ...    64     71    66    109     85    <NA>
# 540804                     163  ...    37     21    12      9     28    <NA>
# 540805                     163  ...    27     15  <NA>     26      6    <NA>
#
#         septiembre  octubre  noviembre  diciembre
# 0              117      146         44         64
# 1              263      132        161        436
# 2             1901     1299       1144       1421
# 3             2496     1403       1629       2040
# 4             1772     1465       1200       1631
# ...            ...      ...        ...        ...
# 540801        <NA>     <NA>       <NA>       <NA>
# 540802        <NA>     <NA>       <NA>       <NA>
# 540803        <NA>     <NA>       <NA>       <NA>
# 540804        <NA>     <NA>       <NA>       <NA>
# 540805        <NA>     <NA>       <NA>       <NA>
#
# [540806 rows x 26 columns]

# %%
# Se eliminan columnas de Provincia, ya que no es necesario para este proyecto

columns_to_drop = ['CUT Provincia Origen','Provincia Origen ','CUT Provincia Destino ', 'Provincia Destino ']

df_viajes_ocasionales = df_viajes_ocasionales.drop(columns=columns_to_drop)

df_viajes_ocasionales
# Out:
#         CUT Comuna Origen Comuna Origen  CUT Region Origen  Region Origen   \
# 0                    1101       Iquique                   1       Tarapacá
# 1                    1101       Iquique                   1       Tarapacá
# 2                    1101       Iquique                   1       Tarapacá
# 3                    1101       Iquique                   1       Tarapacá
# 4                    1101       Iquique                   1       Tarapacá
# ...                   ...           ...                 ...            ...
# 540801              16305   San Nicolás                  16          Ñuble
# 540802              16305   San Nicolás                  16          Ñuble
# 540803              16305   San Nicolás                  16          Ñuble
# 540804              16305   San Nicolás                  16          Ñuble
# 540805              16305   San Nicolás                  16          Ñuble
#
#         CUT Comuna Destino  Comuna Destino              Destino Turistico   \
# 0                      1402          Camiña                         Camiña
# 1                      1403        Colchane  Colchane - P.N. Volcán Isluga
# 2                      1404           Huara          Resto región Tarapacá
# 3                      1405            Pica                           Pica
# 4                      2101     Antofagasta                    Antofagasta
# ...                     ...             ...                            ...
# 540801                16203         Coelemu                Valle del Itata
# 540802                16207        Treguaco             Resto región Ñuble
# 540803                16302        Coihueco             Resto región Ñuble
# 540804                16303          Ñiquén             Resto región Ñuble
# 540805                16304      San Fabián                     San Fabián
#
#         CUT Region Destino  Region Destino   Anio  ...  marzo  abril  mayo  \
# 0                         1        Tarapacá  2019  ...     34    106   100
# 1                         1        Tarapacá  2019  ...    110    139   100
# 2                         1        Tarapacá  2019  ...   1064   2086  1522
# 3                         1        Tarapacá  2019  ...    933   1653  1569
# 4                         2     Antofagasta  2019  ...    899   1069  1850
# ...                     ...             ...   ...  ...    ...    ...   ...
# 540801                   16           Ñuble  2024  ...     15     25     9
# 540802                   16           Ñuble  2024  ...     15     28    39
# 540803                   16           Ñuble  2024  ...     64     71    66
# 540804                   16           Ñuble  2024  ...     37     21    12
# 540805                   16           Ñuble  2024  ...     27     15  <NA>
#
#         junio  julio  agosto  septiembre  octubre  noviembre  diciembre
# 0          15     26      25         117      146         44         64
# 1          69    169     158         263      132        161        436
# 2         973   1574    6450        1901     1299       1144       1421
# 3         935   1485    1613        2496     1403       1629       2040
# 4         749   1116    1644        1772     1465       1200       1631
# ...       ...    ...     ...         ...      ...        ...        ...
# 540801     31      8    <NA>        <NA>     <NA>       <NA>       <NA>
# 540802     57     52    <NA>        <NA>     <NA>       <NA>       <NA>
# 540803    109     85    <NA>        <NA>     <NA>       <NA>       <NA>
# 540804      9     28    <NA>        <NA>     <NA>       <NA>       <NA>
# 540805     26      6    <NA>        <NA>     <NA>       <NA>       <NA>
#
# [540806 rows x 22 columns]

# %%
df_viajes_ocasionales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540806 entries, 0 to 540805
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CUT Comuna Origen       540806 non-null  int64
#  1   Comuna Origen           540806 non-null  object
#  2   CUT Provincia Origen    540806 non-null  int64
#  3   Provincia Origen        540806 non-null  object
#  4   CUT Region Origen       540806 non-null  int64
#  5   Region Origen           540806 non-null  object
#  6   CUT Comuna Destino      540806 non-null  int64
#  7   Comuna Destino          540806 non-null  object
#  8   Destino Turistico       540806 non-null  object
#  9   CUT Provincia Destino   540806 non-null  int64
#  10  Provincia Destino       540806 non-null  object
#  11  CUT Region Destino      540806 non-null  int64
#  12  Region Destino          540806 non-null  object
#  13  Anio                    540806 non-null  int64
#  14  enero                   363777 non-null  Int64
#  15  febrero                 365562 non-null  Int64
#  16  marzo                   302075 non-null  Int64
#  17  abril                   265877 non-null  Int64
#  18  mayo                    276392 non-null  Int64
#  19  junio                   270811 non-null  Int64
#  20  julio                   308959 non-null  Int64
#  21  agosto                  245150 non-null  Int64
#  22  septiembre              260295 non-null  Int64
#  23  octubre                 263942 non-null  Int64
#  24  noviembre               257695 non-null  Int64
#  25  diciembre               281836 non-null  Int64
# dtypes: Int64(12), int64(7), object(7)
# memory usage: 113.5+ MB
