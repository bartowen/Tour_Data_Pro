# %%
import pandas as pd

# %%
# Lectura del DataFrame

df_viajes_ocasionales = pd.read_csv('../data/raw/viajes_ocasionales.csv', sep=';')
df_viajes_ocasionales.head()
# Out:
#    CUT Comuna Origen Comuna Origen  CUT Provincia Origen Provincia Origen   \
# 0               1101       Iquique                    11           Iquique
# 1               1101       Iquique                    11           Iquique
# 2               1101       Iquique                    11           Iquique
# 3               1101       Iquique                    11           Iquique
# 4               1101       Iquique                    11           Iquique
#
#    CUT Region Origen  Region Origen   CUT Comuna Destino  Comuna Destino   \
# 0                   1       Tarapacá                 1402          Camiña
# 1                   1       Tarapacá                 1403        Colchane
# 2                   1       Tarapacá                 1404           Huara
# 3                   1       Tarapacá                 1405            Pica
# 4                   1       Tarapacá                 2101     Antofagasta
#
#               Destino Turistico   CUT Provincia Destino   ...   marzo   abril  \
# 0                         Camiña                      14  ...    34.0   106.0
# 1  Colchane - P.N. Volcán Isluga                      14  ...   110.0   139.0
# 2          Resto región Tarapacá                      14  ...  1064.0  2086.0
# 3                           Pica                      14  ...   933.0  1653.0
# 4                    Antofagasta                      21  ...   899.0  1069.0
#
#      mayo  junio   julio  agosto  septiembre  octubre  noviembre  diciembre
# 0   100.0   15.0    26.0    25.0       117.0    146.0       44.0       64.0
# 1   100.0   69.0   169.0   158.0       263.0    132.0      161.0      436.0
# 2  1522.0  973.0  1574.0  6450.0      1901.0   1299.0     1144.0     1421.0
# 3  1569.0  935.0  1485.0  1613.0      2496.0   1403.0     1629.0     2040.0
# 4  1850.0  749.0  1116.0  1644.0      1772.0   1465.0     1200.0     1631.0
#
# [5 rows x 26 columns]

# %%
# Se eliminan columnas de Provincia, ya que no es necesario para este proyecto

columns_to_drop = ['CUT Provincia Origen','Provincia Origen ','CUT Provincia Destino ', 'Provincia Destino ']

df_viajes_ocasionales = df_viajes_ocasionales.drop(columns=columns_to_drop)

df_viajes_ocasionales
# Out:
#         CUT Comuna Origen Comuna Origen  CUT Region Origen  Region Origen   \
# 0                    1101       Iquique                   1       Tarapacá
# 1                    1101       Iquique                   1       Tarapacá
# 2                    1101       Iquique                   1       Tarapacá
# 3                    1101       Iquique                   1       Tarapacá
# 4                    1101       Iquique                   1       Tarapacá
# ...                   ...           ...                 ...            ...
# 540801              16305   San Nicolás                  16          Ñuble
# 540802              16305   San Nicolás                  16          Ñuble
# 540803              16305   San Nicolás                  16          Ñuble
# 540804              16305   San Nicolás                  16          Ñuble
# 540805              16305   San Nicolás                  16          Ñuble
#
#         CUT Comuna Destino  Comuna Destino              Destino Turistico   \
# 0                      1402          Camiña                         Camiña
# 1                      1403        Colchane  Colchane - P.N. Volcán Isluga
# 2                      1404           Huara          Resto región Tarapacá
# 3                      1405            Pica                           Pica
# 4                      2101     Antofagasta                    Antofagasta
# ...                     ...             ...                            ...
# 540801                16203         Coelemu                Valle del Itata
# 540802                16207        Treguaco             Resto región Ñuble
# 540803                16302        Coihueco             Resto región Ñuble
# 540804                16303          Ñiquén             Resto región Ñuble
# 540805                16304      San Fabián                     San Fabián
#
#         CUT Region Destino  Region Destino   Anio  ...   marzo   abril  \
# 0                         1        Tarapacá  2019  ...    34.0   106.0
# 1                         1        Tarapacá  2019  ...   110.0   139.0
# 2                         1        Tarapacá  2019  ...  1064.0  2086.0
# 3                         1        Tarapacá  2019  ...   933.0  1653.0
# 4                         2     Antofagasta  2019  ...   899.0  1069.0
# ...                     ...             ...   ...  ...     ...     ...
# 540801                   16           Ñuble  2024  ...    15.0    25.0
# 540802                   16           Ñuble  2024  ...    15.0    28.0
# 540803                   16           Ñuble  2024  ...    64.0    71.0
# 540804                   16           Ñuble  2024  ...    37.0    21.0
# 540805                   16           Ñuble  2024  ...    27.0    15.0
#
#           mayo  junio   julio  agosto  septiembre  octubre  noviembre  \
# 0        100.0   15.0    26.0    25.0       117.0    146.0       44.0
# 1        100.0   69.0   169.0   158.0       263.0    132.0      161.0
# 2       1522.0  973.0  1574.0  6450.0      1901.0   1299.0     1144.0
# 3       1569.0  935.0  1485.0  1613.0      2496.0   1403.0     1629.0
# 4       1850.0  749.0  1116.0  1644.0      1772.0   1465.0     1200.0
# ...        ...    ...     ...     ...         ...      ...        ...
# 540801     9.0   31.0     8.0     NaN         NaN      NaN        NaN
# 540802    39.0   57.0    52.0     NaN         NaN      NaN        NaN
# 540803    66.0  109.0    85.0     NaN         NaN      NaN        NaN
# 540804    12.0    9.0    28.0     NaN         NaN      NaN        NaN
# 540805     NaN   26.0     6.0     NaN         NaN      NaN        NaN
#
#         diciembre
# 0            64.0
# 1           436.0
# 2          1421.0
# 3          2040.0
# 4          1631.0
# ...           ...
# 540801        NaN
# 540802        NaN
# 540803        NaN
# 540804        NaN
# 540805        NaN
#
# [540806 rows x 22 columns]

# %%
# Transformación a int

meses = ['enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre','diciembre']
for mes in meses:
    df_viajes_ocasionales[mes] = df_viajes_ocasionales[mes].round(0).astype('Int64')

df_viajes_ocasionales.head()
# Out:
#    CUT Comuna Origen Comuna Origen  CUT Region Origen  Region Origen   \
# 0               1101       Iquique                   1       Tarapacá
# 1               1101       Iquique                   1       Tarapacá
# 2               1101       Iquique                   1       Tarapacá
# 3               1101       Iquique                   1       Tarapacá
# 4               1101       Iquique                   1       Tarapacá
#
#    CUT Comuna Destino  Comuna Destino              Destino Turistico   \
# 0                 1402          Camiña                         Camiña
# 1                 1403        Colchane  Colchane - P.N. Volcán Isluga
# 2                 1404           Huara          Resto región Tarapacá
# 3                 1405            Pica                           Pica
# 4                 2101     Antofagasta                    Antofagasta
#
#    CUT Region Destino  Region Destino   Anio  ...  marzo  abril  mayo  junio  \
# 0                    1        Tarapacá  2019  ...     34    106   100     15
# 1                    1        Tarapacá  2019  ...    110    139   100     69
# 2                    1        Tarapacá  2019  ...   1064   2086  1522    973
# 3                    1        Tarapacá  2019  ...    933   1653  1569    935
# 4                    2     Antofagasta  2019  ...    899   1069  1850    749
#
#    julio  agosto  septiembre  octubre  noviembre  diciembre
# 0     26      25         117      146         44         64
# 1    169     158         263      132        161        436
# 2   1574    6450        1901     1299       1144       1421
# 3   1485    1613        2496     1403       1629       2040
# 4   1116    1644        1772     1465       1200       1631
#
# [5 rows x 22 columns]

# %%
# Eliminar espacios adicionales en los nombres de columnas

df_viajes_ocasionales.columns = df_viajes_ocasionales.columns.str.strip()

df_viajes_ocasionales.head()
# Out:
#    CUT Comuna Origen Comuna Origen  CUT Region Origen Region Origen  \
# 0               1101       Iquique                  1      Tarapacá
# 1               1101       Iquique                  1      Tarapacá
# 2               1101       Iquique                  1      Tarapacá
# 3               1101       Iquique                  1      Tarapacá
# 4               1101       Iquique                  1      Tarapacá
#
#    CUT Comuna Destino Comuna Destino              Destino Turistico  \
# 0                1402         Camiña                         Camiña
# 1                1403       Colchane  Colchane - P.N. Volcán Isluga
# 2                1404          Huara          Resto región Tarapacá
# 3                1405           Pica                           Pica
# 4                2101    Antofagasta                    Antofagasta
#
#    CUT Region Destino Region Destino  Anio  ...  marzo  abril  mayo  junio  \
# 0                   1       Tarapacá  2019  ...     34    106   100     15
# 1                   1       Tarapacá  2019  ...    110    139   100     69
# 2                   1       Tarapacá  2019  ...   1064   2086  1522    973
# 3                   1       Tarapacá  2019  ...    933   1653  1569    935
# 4                   2    Antofagasta  2019  ...    899   1069  1850    749
#
#    julio  agosto  septiembre  octubre  noviembre  diciembre
# 0     26      25         117      146         44         64
# 1    169     158         263      132        161        436
# 2   1574    6450        1901     1299       1144       1421
# 3   1485    1613        2496     1403       1629       2040
# 4   1116    1644        1772     1465       1200       1631
#
# [5 rows x 22 columns]
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
# Aplanar viajes ocasionales por mes.
# id_vars -> Lista de columnas que no se van a transformar (se mantendrán como están)
# value_vars -> Lista de columnas que representan los meses. Estas columnas se "aplanarán" en la nueva columna llamada "Mes"

df_viajes_ocasionales = pd.melt(df_viajes_ocasionales, 
                      id_vars=[ 'CUT Comuna Origen', 'Comuna Origen',
                                'CUT Region Origen', 'Region Origen',
                                'CUT Comuna Destino', 'Comuna Destino', 'Destino Turistico',
                                'CUT Region Destino',
                                'Region Destino', 'Anio'],
                      value_vars=['enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 
                                  'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre'],
                      var_name='Mes', 
                      value_name='Viajes Ocasionales')

df_viajes_ocasionales.head()
