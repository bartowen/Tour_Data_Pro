# %% [markdown]
# # Explore here

# %%
# Your code here

import pandas as pd

# %%
df_viajes_totales = pd.read_csv('https://www.sernatur.cl/wp-content/uploads/2020/11/Viajes-totales-1.csv',sep=';')
df_viajes_ocasionales = pd.read_csv('https://www.sernatur.cl/wp-content/uploads/2020/11/Viajes-ocasionales-1.csv',sep=';')

# %%
df_viajes_ocasionales
# Out:
#         CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                    1101       Iquique                    11
# 1                    1101       Iquique                    11
# 2                    1101       Iquique                    11
# 3                    1101       Iquique                    11
# 4                    1101       Iquique                    11
# ...                   ...           ...                   ...
# 540801              16305   San Nicolás                   163
# 540802              16305   San Nicolás                   163
# 540803              16305   San Nicolás                   163
# 540804              16305   San Nicolás                   163
# 540805              16305   San Nicolás                   163
#
#        Provincia Origen   CUT Region Origen  Region Origen   \
# 0                Iquique                   1       Tarapacá
# 1                Iquique                   1       Tarapacá
# ...

# %%
df_viajes_ocasionales.shape
# Out:
# (540806, 26)

# %%
df_viajes_ocasionales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540806 entries, 0 to 540805
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CUT Comuna Origen       540806 non-null  int64
#  1   Comuna Origen           540806 non-null  object
#  2   CUT Provincia Origen    540806 non-null  int64
#  3   Provincia Origen        540806 non-null  object
#  4   CUT Region Origen       540806 non-null  int64
#  5   Region Origen           540806 non-null  object
#  6   CUT Comuna Destino      540806 non-null  int64
#  7   Comuna Destino          540806 non-null  object
#  8   Destino Turistico       540806 non-null  object
#  9   CUT Provincia Destino   540806 non-null  int64
#  10  Provincia Destino       540806 non-null  object
#  11  CUT Region Destino      540806 non-null  int64
#  12  Region Destino          540806 non-null  object
#  13  Anio                    540806 non-null  int64
# ...

# %%
#strip es para elminar los espacios

df_viajes_totales.columns = df_viajes_totales.columns.str.strip()

# %%
df_viajes_totales.columns
# Out:
# Index(['CUT Comuna Origen', 'Comuna Origen', 'CUT Provincia Origen',
#        'Provincia Origen', 'CUT Region Origen', 'Region Origen',
#        'CUT Comuna Destino', 'Comuna Destino', 'Destino Turistico',
#        'CUT Provincia Destino', 'Provincia Destino', 'CUT Region Destino',
#        'Region Destino', 'Anio', 'enero', 'febrero', 'marzo', 'abril', 'mayo',
#        'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre',
#        'diciembre'],
#       dtype='object')

# %%
df_viajes_totales['Region Destino'].head
# Out:
# <bound method NDFrame.head of 0            Tarapacá
# 1            Tarapacá
# 2            Tarapacá
# 3            Tarapacá
# 4         Antofagasta
#              ...
# 550734          Ñuble
# 550735          Ñuble
# 550736          Ñuble
# 550737          Ñuble
# 550738          Ñuble
# Name: Region Destino, Length: 550739, dtype: object>

# %%
lista_unicos_region_destino = df_viajes_totales['Region Destino'].unique().tolist()

lista_unicos_region_destino
# Out:
# ['Tarapacá',
#  'Antofagasta',
#  'Atacama',
#  'Coquimbo',
#  'Valparaíso',
#  "Libertador Gral. Bernardo O'Higgins",
#  'Maule',
#  'Biobío',
#  'La Araucanía',
#  'Los Lagos',
#  'Aysén del General Carlos Ibáñez del Campo',
#  'Magallanes y de la Antártica Chilena',
#  'Metropolitana de Santiago',
#  'Los Ríos',
#  'Arica y Parinacota',
#  'Ñuble']

# %%
# Unificar Region Destino con PIB Regional. How many turist arrive to region destination?

# %%
#DataSet PIB Regional

df_pib_regional = pd.read_csv('../data/raw/pib_regional.csv',encoding='ISO-8859-1', sep=';')

df_pib_regional
# Out:
#                                    Descripción series   mar.2013   jun.2013  \
# 0                       Región de Arica y Parinacota      278,30     306,13
# 1                                  Región de Tarapacá     811,93     926,81
# 2                               Región de Antofagasta   3.759,32   3.949,00
# 3                                   Región de Atacama     871,76     845,36
# 4                                  Región de Coquimbo   1.426,57   1.413,42
# 5                                Región de Valparaíso   3.339,83   3.371,96
# 6                    Región Metropolitana de Santiago  16.843,14  17.862,99
# 7     Región del Libertador General Bernardo OHiggins   1.931,43   1.708,13
# 8                                    Región del Maule   1.599,50   1.610,47
# 9                                     Región de Ñuble     634,64     650,65
# 10                                  Región del Biobío   2.301,63   2.475,07
# ...

# %%
# Unificar con Región Destinno

lista_unicos_region_destino = df_viajes_totales['Region Destino'].unique().tolist()

lista_unicos_region_destino
# Out:
# ['Tarapacá',
#  'Antofagasta',
#  'Atacama',
#  'Coquimbo',
#  'Valparaíso',
#  "Libertador Gral. Bernardo O'Higgins",
#  'Maule',
#  'Biobío',
#  'La Araucanía',
#  'Los Lagos',
#  'Aysén del General Carlos Ibáñez del Campo',
#  'Magallanes y de la Antártica Chilena',
#  'Metropolitana de Santiago',
#  'Los Ríos',
#  'Arica y Parinacota',
#  'Ñuble']

# %%
lista_unicos_region_destino_pib = df_pib_regional['Descripción series'].unique().tolist()

lista_unicos_region_destino_pib
# Out:
# ['Región de Arica y Parinacota\xa0',
#  'Región de Tarapacá',
#  'Región de Antofagasta',
#  'Región de Atacama',
#  'Región de Coquimbo',
#  'Región de Valparaíso',
#  'Región Metropolitana de Santiago',
#  'Región del Libertador General Bernardo OHiggins',
#  'Región del Maule',
#  'Región de Ñuble',
#  'Región del Biobío',
#  'Región de La Araucanía',
#  'Región de Los Ríos',
#  'Región de Los Lagos',
#  'Región de Aysén del General Carlos Ibáñez del Campo',
#  'Región de Magallanes y de la Antártica Chilena']

# %%
def cambiar_nombres_regiones(df, col_nombre):
    # Diccionario que mapea los nombres originales con "Región" a los nuevos sin "Región"
    mapeo = {
        'Región de Tarapacá': 'Tarapacá',
        'Región de Antofagasta': 'Antofagasta',
        'Región de Atacama': 'Atacama',
        'Región de Coquimbo': 'Coquimbo',
        'Región de Valparaíso': 'Valparaíso',
        'Región Metropolitana de Santiago': 'Metropolitana de Santiago',
        'Región del Libertador General Bernardo OHiggins': 'Libertador General Bernardo OHiggins',
        'Región del Maule': 'Maule',
        'Región de Ñuble': 'Ñuble',
        'Región del Biobío': 'Biobío',
        'Región de La Araucanía': 'La Araucanía',
        'Región de Los Ríos': 'Los Ríos',
        'Región de Los Lagos': 'Los Lagos',
        'Región de Aysén del General Carlos Ibáñez del Campo': 'Aysén del General Carlos Ibáñez del Campo',
        'Región de Magallanes y de la Antártica Chilena': 'Magallanes y de la Antártica Chilena',
        'Región de Arica y Parinacota\xa0': 'Arica y Parinacota'
    }
    
    # Cambiar los nombres en la columna
    df[col_nombre] = df[col_nombre].replace(mapeo)
    
    # Renombrar la columna a 'Destino'
    df = df.rename(columns={col_nombre: 'Destino'})
    
    return df

# %%
cambiar_nombres_regiones(df_pib_regional, 'Descripción series')
# Out:
#                                       Destino   mar.2013   jun.2013  \
# 0                          Arica y Parinacota     278,30     306,13
# 1                                    Tarapacá     811,93     926,81
# 2                                 Antofagasta   3.759,32   3.949,00
# 3                                     Atacama     871,76     845,36
# 4                                    Coquimbo   1.426,57   1.413,42
# 5                                  Valparaíso   3.339,83   3.371,96
# 6                   Metropolitana de Santiago  16.843,14  17.862,99
# 7        Libertador General Bernardo OHiggins   1.931,43   1.708,13
# 8                                       Maule   1.599,50   1.610,47
# 9                                       Ñuble     634,64     650,65
# 10                                     Biobío   2.301,63   2.475,07
# 11                               La Araucanía   1.172,64   1.068,71
# 12                                   Los Ríos     523,44     520,98
# ...

# %%
df_pib_regional
# Out:
#                            Descripción series   mar.2013   jun.2013  \
# 0                          Arica y Parinacota     278,30     306,13
# 1                                    Tarapacá     811,93     926,81
# 2                                 Antofagasta   3.759,32   3.949,00
# 3                                     Atacama     871,76     845,36
# 4                                    Coquimbo   1.426,57   1.413,42
# 5                                  Valparaíso   3.339,83   3.371,96
# 6                   Metropolitana de Santiago  16.843,14  17.862,99
# 7        Libertador General Bernardo OHiggins   1.931,43   1.708,13
# 8                                       Maule   1.599,50   1.610,47
# 9                                       Ñuble     634,64     650,65
# 10                                     Biobío   2.301,63   2.475,07
# 11                               La Araucanía   1.172,64   1.068,71
# 12                                   Los Ríos     523,44     520,98
# ...

# %%
lista_unicos_destino_turs = df_viajes_totales['Destino Turistico'].unique().tolist()

lista_unicos_destino_turs
# Out:
# ['Camiña',
#  'Colchane - P.N. Volcán Isluga',
#  'Resto región Tarapacá',
#  'Pica',
#  'Antofagasta',
#  'Mejillones',
#  'Resto región Antofagasta',
#  'Taltal',
#  'Calama - Alto El Loa',
#  'San Pedro de Atacama',
#  'Tocopilla',
#  'María Elena y Pedro de Valdivia',
#  'Valle de Copiapó y Cordillera de Atacama',
#  'Bahía inglesa - PN. Pan de Azúcar',
#  'Resto región Atacama',
#  'Valle del Huasco y Cetáceos del Desierto',
#  'La Serena - Coquimbo',
#  'Antakari',
#  'Punta de Choros - R.N. Pingüino de Humboldt',
#  'Valle del Elqui',
#  'Valle Choapa',
#  'Resto región Coquimbo',
#  'Litoral Los Vilos - Pichidangui/ Quilimarí',
#  'Ovalle - P.N. Fray Jorge',
#  'Valles del Limarí',
#  'Valparaíso',
#  'Valle de Casablanca',
#  'Litoral Viña del Mar - Concón',
#  'Litoral Ritoque-Los Molles',
#  'Rapa Nui',
#  'Valle del Aconcagua',
#  'Resto región Valparaíso',
#  'Reserva de la Biosfera Parque Nacional La Campana.',
#  'Litoral de los Poetas',
#  'Cachapoal',
# ...

# %%
df_viajes_ocasionales
# Out:
#         CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                    1101       Iquique                    11
# 1                    1101       Iquique                    11
# 2                    1101       Iquique                    11
# 3                    1101       Iquique                    11
# 4                    1101       Iquique                    11
# ...                   ...           ...                   ...
# 540801              16305   San Nicolás                   163
# 540802              16305   San Nicolás                   163
# 540803              16305   San Nicolás                   163
# 540804              16305   San Nicolás                   163
# 540805              16305   San Nicolás                   163
#
#        Provincia Origen   CUT Region Origen  Region Origen   \
# 0                Iquique                   1       Tarapacá
# 1                Iquique                   1       Tarapacá
# ...

# %%
print("Hola Mundo!")
# Out:
# Hola Mundo!
