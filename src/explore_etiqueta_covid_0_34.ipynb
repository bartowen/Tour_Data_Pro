# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed/df_segmento_0-34.csv',sep=';')

df
# Out:
#          CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                     1101       Iquique                    11
# 1                     1101       Iquique                    11
# 2                     1101       Iquique                    11
# 3                     1101       Iquique                    11
# 4                     1101       Iquique                    11
# ...                    ...           ...                   ...
# 2175256              16305   San Nicolás                   163
# 2175257              16305   San Nicolás                   163
# 2175258              16305   San Nicolás                   163
# 2175259              16305   San Nicolás                   163
# 2175260              16305   San Nicolás                   163
#
#         Provincia Origen  CUT Region Origen Region Origen  CUT Comuna Destino  \
# 0                Iquique                  1      Tarapacá                1402
# 1                Iquique                  1      Tarapacá                1402
# 2                Iquique                  1      Tarapacá                1402
# 3                Iquique                  1      Tarapacá                1402
# 4                Iquique                  1      Tarapacá                1402
# ...                  ...                ...           ...                 ...
# 2175256          Punilla                 16         Ñuble               16304
# 2175257          Punilla                 16         Ñuble               16304
# 2175258          Punilla                 16         Ñuble               16304
# 2175259          Punilla                 16         Ñuble               16304
# 2175260          Punilla                 16         Ñuble               16304
#
#         Comuna Destino  CUT Provincia Destino Provincia Destino  \
# 0               Camiña                     14         Tamarugal
# 1               Camiña                     14         Tamarugal
# 2               Camiña                     14         Tamarugal
# 3               Camiña                     14         Tamarugal
# 4               Camiña                     14         Tamarugal
# ...                ...                    ...               ...
# 2175256     San Fabián                    163           Punilla
# 2175257     San Fabián                    163           Punilla
# 2175258     San Fabián                    163           Punilla
# 2175259     San Fabián                    163           Punilla
# 2175260     San Fabián                    163           Punilla
#
#          CUT Region Destino Region Destino  Anio  CUT Mes        Mes  \
# 0                         1       Tarapacá  2019        3      marzo
# 1                         1       Tarapacá  2019        6      junio
# 2                         1       Tarapacá  2019        7      julio
# 3                         1       Tarapacá  2019        8     agosto
# 4                         1       Tarapacá  2020        4      abril
# ...                     ...            ...   ...      ...        ...
# 2175256                  16          Ñuble  2023        7      julio
# 2175257                  16          Ñuble  2023        8     agosto
# 2175258                  16          Ñuble  2023       10    octubre
# 2175259                  16          Ñuble  2023       11  noviembre
# 2175260                  16          Ñuble  2023       12  diciembre
#
#          CUT Temporada Temporada  PIB Region Origen  PIB Region Destino  \
# 0                    0      Baja        1061.580205         1061.580205
# 1                    0      Baja        1115.801838         1115.801838
# 2                    1      Alta        1180.893537         1180.893537
# 3                    0      Baja        1180.893537         1180.893537
# 4                    0      Baja        1042.268636         1042.268636
# ...                ...       ...                ...                 ...
# 2175256              1      Alta         737.064697          737.064697
# 2175257              0      Baja         737.064697          737.064697
# 2175258              0      Baja         833.567298          833.567298
# 2175259              0      Baja         833.567298          833.567298
# 2175260              1      Alta         833.567298          833.567298
#
#          Viajes Ocasionales
# 0                        34
# 1                        15
# 2                        26
# 3                        25
# 4                        34
# ...                     ...
# 2175256                  15
# 2175257                  12
# 2175258                  21
# 2175259                  15
# 2175260                  26
#
# [2175261 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['CUT Comuna Origen', 'Comuna Origen', 'CUT Provincia Origen',
#        'Provincia Origen', 'CUT Region Origen', 'Region Origen',
#        'CUT Comuna Destino', 'Comuna Destino', 'CUT Provincia Destino',
#        'Provincia Destino', 'CUT Region Destino', 'Region Destino', 'Anio',
#        'CUT Mes', 'Mes', 'CUT Temporada', 'Temporada', 'PIB Region Origen',
#        'PIB Region Destino', 'Viajes Ocasionales'],
#       dtype='object')

# %%
# Crear columna 'covid_periodo' con valores 0 o 1
df['covid_periodo_num'] = df['Anio'].apply(lambda x: 1 if x in [2020, 2021] else 0)

# Crear columna 'covid_periodo_texto' con valores 'Sí' o 'No'
df['covid_periodo'] = df['Anio'].apply(lambda x: 'Sí' if x in [2020, 2021] else 'No')

df
# Out:
#          CUT Comuna Origen Comuna Origen  CUT Provincia Origen  \
# 0                     1101       Iquique                    11
# 1                     1101       Iquique                    11
# 2                     1101       Iquique                    11
# 3                     1101       Iquique                    11
# 4                     1101       Iquique                    11
# ...                    ...           ...                   ...
# 2175256              16305   San Nicolás                   163
# 2175257              16305   San Nicolás                   163
# 2175258              16305   San Nicolás                   163
# 2175259              16305   San Nicolás                   163
# 2175260              16305   San Nicolás                   163
#
#         Provincia Origen  CUT Region Origen Region Origen  CUT Comuna Destino  \
# 0                Iquique                  1      Tarapacá                1402
# 1                Iquique                  1      Tarapacá                1402
# 2                Iquique                  1      Tarapacá                1402
# 3                Iquique                  1      Tarapacá                1402
# 4                Iquique                  1      Tarapacá                1402
# ...                  ...                ...           ...                 ...
# 2175256          Punilla                 16         Ñuble               16304
# 2175257          Punilla                 16         Ñuble               16304
# 2175258          Punilla                 16         Ñuble               16304
# 2175259          Punilla                 16         Ñuble               16304
# 2175260          Punilla                 16         Ñuble               16304
#
#         Comuna Destino  CUT Provincia Destino Provincia Destino  ...  Anio  \
# 0               Camiña                     14         Tamarugal  ...  2019
# 1               Camiña                     14         Tamarugal  ...  2019
# 2               Camiña                     14         Tamarugal  ...  2019
# 3               Camiña                     14         Tamarugal  ...  2019
# 4               Camiña                     14         Tamarugal  ...  2020
# ...                ...                    ...               ...  ...   ...
# 2175256     San Fabián                    163           Punilla  ...  2023
# 2175257     San Fabián                    163           Punilla  ...  2023
# 2175258     San Fabián                    163           Punilla  ...  2023
# 2175259     San Fabián                    163           Punilla  ...  2023
# 2175260     San Fabián                    163           Punilla  ...  2023
#
#         CUT Mes        Mes  CUT Temporada Temporada  PIB Region Origen  \
# 0             3      marzo              0      Baja        1061.580205
# 1             6      junio              0      Baja        1115.801838
# 2             7      julio              1      Alta        1180.893537
# 3             8     agosto              0      Baja        1180.893537
# 4             4      abril              0      Baja        1042.268636
# ...         ...        ...            ...       ...                ...
# 2175256       7      julio              1      Alta         737.064697
# 2175257       8     agosto              0      Baja         737.064697
# 2175258      10    octubre              0      Baja         833.567298
# 2175259      11  noviembre              0      Baja         833.567298
# 2175260      12  diciembre              1      Alta         833.567298
#
#         PIB Region Destino  Viajes Ocasionales  covid_periodo_num  \
# 0              1061.580205                  34                  0
# 1              1115.801838                  15                  0
# 2              1180.893537                  26                  0
# 3              1180.893537                  25                  0
# 4              1042.268636                  34                  1
# ...                    ...                 ...                ...
# 2175256         737.064697                  15                  0
# 2175257         737.064697                  12                  0
# 2175258         833.567298                  21                  0
# 2175259         833.567298                  15                  0
# 2175260         833.567298                  26                  0
#
#          covid_periodo
# 0                   No
# 1                   No
# 2                   No
# 3                   No
# 4                   Sí
# ...                ...
# 2175256             No
# 2175257             No
# 2175258             No
# 2175259             No
# 2175260             No
#
# [2175261 rows x 22 columns]

# %%
df_num = df.drop(['Comuna Origen', 'Provincia Origen', 'Region Origen', 'Comuna Destino','Provincia Destino', 'Region Destino', 'Mes', 'Temporada','covid_periodo'],axis=1)
df_num
# Out:
#          CUT Comuna Origen  CUT Provincia Origen  CUT Region Origen  \
# 0                     1101                    11                  1
# 1                     1101                    11                  1
# 2                     1101                    11                  1
# 3                     1101                    11                  1
# 4                     1101                    11                  1
# ...                    ...                   ...                ...
# 2175256              16305                   163                 16
# 2175257              16305                   163                 16
# 2175258              16305                   163                 16
# 2175259              16305                   163                 16
# 2175260              16305                   163                 16
#
#          CUT Comuna Destino  CUT Provincia Destino  CUT Region Destino  Anio  \
# 0                      1402                     14                   1  2019
# 1                      1402                     14                   1  2019
# 2                      1402                     14                   1  2019
# 3                      1402                     14                   1  2019
# 4                      1402                     14                   1  2020
# ...                     ...                    ...                 ...   ...
# 2175256               16304                    163                  16  2023
# 2175257               16304                    163                  16  2023
# 2175258               16304                    163                  16  2023
# 2175259               16304                    163                  16  2023
# 2175260               16304                    163                  16  2023
#
#          CUT Mes  CUT Temporada  PIB Region Origen  PIB Region Destino  \
# 0              3              0        1061.580205         1061.580205
# 1              6              0        1115.801838         1115.801838
# 2              7              1        1180.893537         1180.893537
# 3              8              0        1180.893537         1180.893537
# 4              4              0        1042.268636         1042.268636
# ...          ...            ...                ...                 ...
# 2175256        7              1         737.064697          737.064697
# 2175257        8              0         737.064697          737.064697
# 2175258       10              0         833.567298          833.567298
# 2175259       11              0         833.567298          833.567298
# 2175260       12              1         833.567298          833.567298
#
#          Viajes Ocasionales  covid_periodo_num
# 0                        34                  0
# 1                        15                  0
# 2                        26                  0
# 3                        25                  0
# 4                        34                  1
# ...                     ...                ...
# 2175256                  15                  0
# 2175257                  12                  0
# 2175258                  21                  0
# 2175259                  15                  0
# 2175260                  26                  0
#
# [2175261 rows x 13 columns]

# %%
target_variable = 'Viajes Ocasionales'

# Crear x_train y x_test excluyendo la columna objetivo

X_train = df_num[df['Anio'] != 2023].drop(columns=[target_variable])
X_test = df_num[df_num['Anio'] == 2023].drop(columns=[target_variable])

# Crear y_train y y_test con solo la columna objetivo

y_train = df_num[df_num['Anio'] != 2023][target_variable]
y_test = df_num[df_num['Anio'] == 2023][target_variable]

X_test
# Out:
#          CUT Comuna Origen  CUT Provincia Origen  CUT Region Origen  \
# 20                    1101                    11                  1
# 21                    1101                    11                  1
# 22                    1101                    11                  1
# 23                    1101                    11                  1
# 24                    1101                    11                  1
# ...                    ...                   ...                ...
# 2175256              16305                   163                 16
# 2175257              16305                   163                 16
# 2175258              16305                   163                 16
# 2175259              16305                   163                 16
# 2175260              16305                   163                 16
#
#          CUT Comuna Destino  CUT Provincia Destino  CUT Region Destino  Anio  \
# 20                     2202                     22                   2  2023
# 21                     2202                     22                   2  2023
# 22                     2202                     22                   2  2023
# 23                     2202                     22                   2  2023
# 24                     2202                     22                   2  2023
# ...                     ...                    ...                 ...   ...
# 2175256               16304                    163                  16  2023
# 2175257               16304                    163                  16  2023
# 2175258               16304                    163                  16  2023
# 2175259               16304                    163                  16  2023
# 2175260               16304                    163                  16  2023
#
#          CUT Mes  CUT Temporada  PIB Region Origen  PIB Region Destino  \
# 20             1              1        1172.444308         3806.672045
# 21             2              1        1172.444308         3806.672045
# 22             3              0        1172.444308         3806.672045
# 23             4              0        1155.646190         3836.066866
# 24             5              0        1155.646190         3836.066866
# ...          ...            ...                ...                 ...
# 2175256        7              1         737.064697          737.064697
# 2175257        8              0         737.064697          737.064697
# 2175258       10              0         833.567298          833.567298
# 2175259       11              0         833.567298          833.567298
# 2175260       12              1         833.567298          833.567298
#
#          covid_periodo_num
# 20                       0
# 21                       0
# 22                       0
# 23                       0
# 24                       0
# ...                    ...
# 2175256                  0
# 2175257                  0
# 2175258                  0
# 2175259                  0
# 2175260                  0
#
# [457436 rows x 12 columns]

# %%
from xgboost import XGBRegressor

model = XGBRegressor(random_state = 42)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([12.2716255, 11.212559 , 14.227817 , ..., 18.389498 , 17.982496 ,
#        19.35243  ], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

print(f'El MAE es: {mean_absolute_error(y_test, y_pred)}')
print(f'El MSE es: {mean_squared_error(y_test, y_pred)}')
print(f'El RMSE es: {np.sqrt(mean_squared_error(y_test, y_pred))}')
print(f'El R2 es: {r2_score(y_test, y_pred)}')
# Out:
# El MAE es: 5.646936345933246
# El MSE es: 51.48389111652654
# El RMSE es: 7.175227600329243
# El R2 es: 0.2466667890548706

# %%
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, root_mean_squared_error

# Selección de características con SelectKBest
selector = SelectKBest(score_func=f_regression, k=8)
X_train_sel = selector.fit_transform(X_train, y_train)

# Transformación de los datos de test con las mismas características seleccionadas
X_test_sel = selector.transform(X_test)

# Obtener las columnas seleccionadas
selected_features = selector.get_support(indices=True)
best_columns = X_train.columns[selected_features]
print("Columnas seleccionadas:", best_columns)

# Ahora, puedes proceder a entrenar el modelo con las características seleccionadas
# Normalización de los datos usando MinMaxScaler (opcional, dependiendo de tu modelo)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_sel)
X_test_scaled = scaler.transform(X_test_sel)

# Crear el modelo de Random Forest
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train_scaled, y_train)

# Realizar predicciones
y_pred = model.predict(X_test_scaled)

# Evaluar el modelo
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# Columnas seleccionadas: Index(['CUT Comuna Origen', 'CUT Provincia Origen', 'CUT Region Origen',
#        'Anio', 'CUT Mes', 'CUT Temporada', 'PIB Region Origen',
#        'covid_periodo_num'],
#       dtype='object')
